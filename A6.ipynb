# %% [markdown]
# In these examples, we will look at some cross-linguistic word form data and study some models that allow us to look at optimal phylogenies. We will use data from the following paper.
#
#
# [Dellert, Johannes, Daneyko, T., Muench, A., Ladygina, A., Buch, A., Clarius, N., Grigorjew, I., Balabel, M., Boga, H. I., Baysarova, Z., Muehlenbernd, R., Wahle, J., and Jaeger, G. (2020). Northeuralex: A wide-coverage lexical database of northern eurasia. Language Resources & Evaluation, 54(273–301).](https://drive.google.com/file/d/1ptoMNctdJs99wPWfBUGbw4_X60NtKl9B/view?usp=sharing)
#
# This data was can be found [here](http://northeuralex.org/) as well.
#
# Copy the data to your drive folder from: [here](https://drive.google.com/file/d/1Mfa8XayBFJb0fY8wfinODw90yuRal8AD/view?usp=sharing), [here](https://drive.google.com/file/d/1AQqkscWKlq3quw-BWjB8xqSQzm7-uDtt/view?usp=sharing), and [here](https://drive.google.com/file/d/1R7ZLEzDW9QKUen3BjItPsySaUPCpu7xk/view?usp=sharing).

# %% [markdown]
# ***Question 1:*** What is the Northeuralex dataset? Give a brief overview. What kind of data is it? What is its purpose? How was it constructed? No need to go into all of the particulars (such as fields of the files), just give an overview of no more than one paragraph that gives the gist for someone unfamiliar with the dataset.
#
# **Q1: put your answer here (please keep it brief, 3-5 sentences)**
#
# Northeuralex is a lexical database which covers core 1016 vocabulary concepts across 107 languages from Northern Eurasia. It includes phonetical transcription in IPA format, as well as additional information like labelled semantic categories and ranking of the basicness of concepts. To obtain the data, a list of 1016 concepts was created with consideration for its relevance to place/time and for reducing overlaps in meaning. Corresponding words in all languages were obtained by a systematic process that extracts data from dictionary resources in source languages with reverse lookup for verification. Phonetic representation was first created by a transcription program that is directed by the language's pronounciation rules. Experts in relevant languages provided feedback to ensure the quality of word selection and transcription. The purpose of the dataset is to aid the study of historical linguistics by allowing easy lookup of information that would otherwise have to be searched for in individual dictionaries. For example, it could be used to detect cognates which underwent semantic shifts, infer contact events between languages, or investigate the correlation between phoneme size with population size/geographical isolation.
#
#
#
#
# Let's read in the wordforms in this dataset.

# %%
from google.colab import drive
drive.mount('/content/drive/')

import pandas as pd
wordforms=pd.read_csv("/content/drive/My Drive/northeuralex.csv")
display(wordforms)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#        Language_ID Glottocode      Concept_ID  ...      List     Dolgo Next_Step
# 0              fin   finn1318         Auge::N  ...     SILME     SVRMV  validate
# 1              fin   finn1318          Ohr::N  ...     KURWA     KVRWV  validate
# 2              fin   finn1318         Nase::N  ...      NENE      NVNV  validate
# 3              fin   finn1318         Mund::N  ...        SY        SV  validate
# 4              fin   finn1318         Zahn::N  ...     HAMAS     HVMVS  validate
# ...            ...        ...             ...  ...       ...       ...       ...
# 121608         cmn   mand1415    verkaufen::V  ...       MAI        MV  validate
# 121609         cmn   mand1415     bezahlen::V  ...  BY_CJE2N  PV_KJV1N  validate
# 121610         cmn   mand1415       zahlen::V  ...     CI1BY     KV1PV  validate
# 121611         cmn   mand1415  beherrschen::V  ...    TY2NCI    TV1NKV  validate
# 121612         cmn   mand1415     ertragen::V  ...   RE2NNAI    RV1NNV  validate
#
# [121613 rows x 10 columns]

# %% [markdown]
# ***Question 2:*** Describe the meaning of the `Langauge_ID`, `Concept_ID`, `rawIPA` and `IPA` columns of the data.
#
# **Q2: put your answer here (please keep it brief, no more than 1 sentence per column)**
#
# Language_ID: Which language the word is from, e.g. "fin" is Finnish and "cmn" is Mangarin Chinese.
#
# Concept_ID: The concept word in German since that was the main reference language, and semantic category, e.g. "V" for verb
#
# rawIPA: Pronounciation in "International Phonetic Alphabet" which provides a unique symbol for each distinctive sound.
#
# IPA: A more processed form of rawIPA that is sure to be uniform between languages
#
# Now let's read in some metadata about the languages.

# %%
languages=pd.read_csv("/content/drive/My Drive/northeuralex-languages.csv")
display(languages)
# Out:
#                  name glotto_code iso_code  ...     subfamily latitude  longitude
# 0             Finnish    finn1318      fin  ...        Finnic  61.0000    24.4500
# 1      North Karelian    kare1335      krl  ...        Finnic  65.1691    30.8655
# 2    Olonets Karelian    livv1243      olo  ...        Finnic  61.0000    33.0000
# 3                Veps    veps1250      vep  ...        Finnic  60.3353    34.7865
# 4            Estonian    esto1258      ekk  ...        Finnic  59.2500    24.7500
# ..                ...         ...      ...  ...           ...      ...        ...
# 102            Dargwa    darg1241      dar  ...  Daghestanian  42.4257    47.4388
# 103           Chechen    chec1245      che  ...          Nakh  43.5000    45.5000
# 104   Standard Arabic    stan1318      arb  ...       Semitic  27.9625    43.8525
# 105     Modern Hebrew    hebr1245      heb  ...       Semitic  31.1056    35.0179
# 106  Mandarin Chinese    mand1415      cmn  ...       Sinitic  40.0209   116.2280
#
# [107 rows x 7 columns]

# %% [markdown]
# ***Question 3:*** Describe the meaning of the `Family`, `iso_code`, and `subfamily` columns of the data.
#
# **Q3: put your answer here (please keep it brief, no more than 1 sentence per column)**
#
# Family: Which group the language belongs to based on its phylogenetically-derived origin, languages in the same family are derived from a common ancestor
#
# Iso_code: The 3-symbol code of the language in "International Organization for Standardization" format, e.g. "fin" is Finnish; like "Language_ID" in the first table
#
# Subfamily: Which smaller group within the family a lanugage belongs to based on its origin
#
#
#
# Now let's read in some further data about the concepts.

# %%
concepts=pd.read_csv("/content/drive/My Drive/northeuralex-concepts.csv")
display(concepts)
# Out:
#       number  position_in_ranking  ... concepticon_proposed comments
# 0          1                   44  ...                  EYE      NaN
# 1          2                   34  ...                  EAR      NaN
# 2          3                  149  ...                 NOSE      NaN
# 3          4                   25  ...                MOUTH      NaN
# 4          5                   31  ...                TOOTH      NaN
# ...      ...                  ...  ...                  ...      ...
# 1011    1012                  140  ...                 SELL      NaN
# 1012    1013                  198  ...              PAY_FOR      NaN
# 1013    1014                  235  ...                  PAY      NaN
# 1014    1015                  899  ...                 RULE      NaN
# 1015    1016                  751  ...               ENDURE      NaN
#
# [1016 rows x 13 columns]

# %% [markdown]
# ***Question 4:*** Describe the meaning of the `id_nelex`, `gloss_en`, and `position_in_ranking` columns of the data.
#
# **Q4: put your answer here (please keep it brief, no more than 1 sentence per column)**
#
# ID_nelex: The same "Concept_ID" in the first table
#
# Gloss_en: The concept word in English
#
# Position_in_ranking: A ranking of basicness of the concept, accounting for it being simple and distinct from other concepts, e.g. "eye" is more basic than "endure" since it has a lower ranking
#
#
# It will be useful to merge all of the meta-information into the main wordforms dataframe.

# %%
# Problem 1a: rename the approproate columns in the languages and concepts dataframes to make this merge possible.
languages.rename(columns={"iso_code": "Language_ID"}, inplace=True)
concepts.rename(columns={"id_nelex": "Concept_ID"}, inplace=True)

#display(languages)
#languages.columns
#wordforms.columns

# Problem 1b: Use the merge function to merge the three dataframes into one.
#your code here

wordforms2 = pd.merge(wordforms, languages)
wordforms3 = pd.merge(wordforms2, concepts)
wordforms = wordforms3
display(wordforms)
# Out:
#        Language_ID Glottocode  ... concepticon_proposed comments
# 0              fin   finn1318  ...                  EYE      NaN
# 1              krl   kare1335  ...                  EYE      NaN
# 2              olo   livv1243  ...                  EYE      NaN
# 3              vep   veps1250  ...                  EYE      NaN
# 4              ekk   esto1258  ...                  EYE      NaN
# ...            ...        ...  ...                  ...      ...
# 121608         heb   hebr1245  ...               ENDURE      NaN
# 121609         cmn   mand1415  ...               ENDURE      NaN
# 121610         bua   buri1258  ...               ENDURE      NaN
# 121611         bua   buri1258  ...               ENDURE      NaN
# 121612         ava   avar1256  ...               ENDURE      NaN
#
# [121613 rows x 28 columns]

# %% [markdown]
# In this problem set, we will make use of the `lingpy` package of tools for historical linguistics. You can find more information on this [here](https://lingpy.org/index.html). We'll start by installing the package.

# %%
# !pip install lingpy
# Out:
# Collecting lingpy
#   Downloading https://files.pythonhosted.org/packages/e4/80/0b2581720cd3edfa0beedf85cc5bce85641d2afd3d7dc144f62668421844/lingpy-2.6.6.tar.gz (3.0MB)
#      |████████████████████████████████| 3.0MB 8.9MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from lingpy) (1.19.4)
# Collecting appdirs
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Collecting networkx<=2.2,>=2.0
#   Downloading https://files.pythonhosted.org/packages/f3/f4/7e20ef40b118478191cec0b58c3192f822cace858c19505c7670961b76b2/networkx-2.2.zip (1.7MB)
#      |████████████████████████████████| 1.7MB 38.3MB/s
# Collecting nose
#   Downloading https://files.pythonhosted.org/packages/15/d8/dd071918c040f50fa1cf80da16423af51ff8ce4a0f2399b7bf8de45ac3d9/nose-1.3.7-py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 39.7MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from lingpy) (4.41.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from lingpy) (1.15.0)
# Collecting mock
#   Downloading https://files.pythonhosted.org/packages/5c/03/b7e605db4a57c0f6fba744b11ef3ddf4ddebcada35022927a2b5fc623fdf/mock-4.0.3-py3-none-any.whl
# Collecting csvw>=1.5.6
#   Downloading https://files.pythonhosted.org/packages/91/c1/9f615dc3535aace5f6ddcc4411351996ff2f868f4d16703d13161fcef2bd/csvw-1.8.1-py2.py3-none-any.whl
# Collecting clldutils>=2.8.0
#   Downloading https://files.pythonhosted.org/packages/7b/2a/98cf97f13af7503edd210bf0d1333ef77be2ebc74bb624afacc789d8336a/clldutils-3.6.0-py2.py3-none-any.whl (189kB)
#      |████████████████████████████████| 194kB 37.0MB/s
# Collecting pycldf>=1.7.0
#   Downloading https://files.pythonhosted.org/packages/e5/36/a13a10e08989826c01078dd14ce742d20dd7b11416fa74896e5a89497939/pycldf-1.17.0-py2.py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 5.8MB/s
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx<=2.2,>=2.0->lingpy) (4.4.2)
# Collecting isodate
#   Downloading https://files.pythonhosted.org/packages/9b/9f/b36f7774ff5ea8e428fdcfc4bb332c39ee5b9362ddd3d40d9516a55221b2/isodate-0.6.0-py2.py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 5.9MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from csvw>=1.5.6->lingpy) (2.8.1)
# Requirement already satisfied: uritemplate>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from csvw>=1.5.6->lingpy) (3.0.1)
# Requirement already satisfied: attrs>=18.1 in /usr/local/lib/python3.6/dist-packages (from csvw>=1.5.6->lingpy) (20.3.0)
# Collecting rfc3986
#   Downloading https://files.pythonhosted.org/packages/78/be/7b8b99fd74ff5684225f50dd0e865393d2265656ef3b4ba9eaaaffe622b8/rfc3986-1.4.0-py2.py3-none-any.whl
# Collecting colorlog
#   Downloading https://files.pythonhosted.org/packages/4e/c8/c16d30bbed11a1722060014c246d124582d1f781b26f5859d8dacc3e08e1/colorlog-4.6.2-py2.py3-none-any.whl
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.6/dist-packages (from clldutils>=2.8.0->lingpy) (0.8.7)
# Collecting pybtex; python_version > "3.5"
#   Downloading https://files.pythonhosted.org/packages/15/ef/9f93c1084aef4dcd190c86a9e405e97b065a96514c74ce34b2fd5c02fe73/pybtex-0.23.0-py2.py3-none-any.whl (279kB)
#      |████████████████████████████████| 286kB 40.7MB/s
# Collecting latexcodec>=1.0.4
#   Downloading https://files.pythonhosted.org/packages/0a/76/9552dfc6b74c2d6c3f199e927d41998dc1e561b7cbe4af7e7247388e17e8/latexcodec-2.0.1-py2.py3-none-any.whl
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.6/dist-packages (from pybtex; python_version > "3.5"->pycldf>=1.7.0->lingpy) (3.13)
# Building wheels for collected packages: lingpy, networkx
#   Building wheel for lingpy (setup.py) ... done
#   Created wheel for lingpy: filename=lingpy-2.6.6-cp36-none-any.whl size=1263437 sha256=c839252392fb951b2efef497c094c7e7ab02e7a2408180d4189130d0928667f7
#   Stored in directory: /root/.cache/pip/wheels/d6/95/95/98f4bb29280d4602ee2032395b850c845bcc837e8cd6f9a6a8
#   Building wheel for networkx (setup.py) ... done
#   Created wheel for networkx: filename=networkx-2.2-py2.py3-none-any.whl size=1527322 sha256=05ce81863fc085e9bcd37ac27fb347e4bfd920c73db47104e92633c82dae7bef
#   Stored in directory: /root/.cache/pip/wheels/68/f8/29/b53346a112a07d30a5a84d53f19aeadaa1a474897c0423af91
# Successfully built lingpy networkx
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: appdirs, networkx, nose, mock, isodate, rfc3986, csvw, colorlog, clldutils, latexcodec, pybtex, pycldf, lingpy
#   Found existing installation: networkx 2.5
#     Uninstalling networkx-2.5:
#       Successfully uninstalled networkx-2.5
# Successfully installed appdirs-1.4.4 clldutils-3.6.0 colorlog-4.6.2 csvw-1.8.1 isodate-0.6.0 latexcodec-2.0.1 lingpy-2.6.6 mock-4.0.3 networkx-2.2 nose-1.3.7 pybtex-0.23.0 pycldf-1.17.0 rfc3986-1.4.0

# %% [markdown]
# In order to make our computations below more manageable, we will focus on the Indo-european languages which you can read more about [here](https://en.wikipedia.org/wiki/Indo-European_languages). We will also focus just on the top 20 concepts as determined by their rank.

# %%
#Problem 2a: Filter out the non-Indo-European languages from the wordforms and languages dataframes
indo_eur = wordforms[wordforms['family'] == "Indo-European"]

#Problem 2b: Filter our the concepts which appear less than or equal to rank 20 in the concepts dataframe.
max_rank=20
top_concepts = indo_eur[indo_eur['position_in_ranking'] <= max_rank]
display(top_concepts)
# Out:
#        Language_ID Glottocode  ... concepticon_proposed comments
# 7163           ben   beng1280  ...                WATER      NaN
# 7164           hin   hind1269  ...                WATER      NaN
# 7165           hin   hind1269  ...                WATER      NaN
# 7166           pbu   nort2646  ...                WATER      NaN
# 7167           pes   west2369  ...                WATER      NaN
# ...            ...        ...  ...                  ...      ...
# 107539         cat   stan1289  ...                 GIVE      NaN
# 107540         spa   stan1288  ...                 GIVE      NaN
# 107541         por   port1283  ...                 GIVE      NaN
# 107542         ita   ital1282  ...                 GIVE      NaN
# 107543         ron   roma1327  ...                 GIVE      NaN
#
# [817 rows x 28 columns]

# %% [markdown]
# Our goal is to use agglomerative clustering to try to reconstruct the tree for the indoeuropean languages. You can find a reference tree (for families) [here](https://en.wikipedia.org/wiki/Indo-European_languages#/media/File:IndoEuropeanLanguageFamilyRelationsChart.jpg).
#
# In order to do this, we will need to construct a  matrix of similarities between the languages, called a confusion matrix.
#
# We will compute the (normalized) levenshtein distance between the strings for each concept for each pair of languages. For instance, we we will compute the normalized levenshtein distance between the words for Auge::N (eye in English) for German and English and then similarily for all 19 other concepts. We will then average these values to find the similarity between German and English. We will do this for all pairs of languages to create a list of lists representing the confusion matrix.
#
# Note that running your code will take a few minutes.

# %%
import lingpy as lp
import numpy as np
from statistics import mean

#initialize confusion matrix
language_list = top_concepts.name.unique()
concept_list = top_concepts.Concept_ID.unique()
confusion= [[0 for j in range(len(language_list))] for i in range(len(language_list))]

#Problem 3: fill the confusion matrix  using the 
#lp.align.pairwise.edit_dist function from lingpy, on 
#the "IPA" fields for each language.

print("language list length: ", len(language_list))
print("confusion list: ", len(confusion[0]))
print(language_list)

language1_ind=0
language2_ind=0

for language1 in language_list:
  for language2 in language_list:

    #list of distances 
    distances=[]

    #iterate through top 20 concepts
    for concept in concept_list:
      temp = top_concepts[(top_concepts['Concept_ID'] == concept) & ((top_concepts['name'] == language1) | (top_concepts['name'] == language2))]
      IPA_1=""
      IPA_2=""
      #iterate through the dataframe to find the two IPAs of the given concept in the gigven languages
      for index, row in temp.iterrows(): 
        if(row["Concept_ID"]==concept and row["name"]==language1):
          IPA_1=row["IPA"]
        if(row["Concept_ID"]==concept and row["name"]==language2):
          IPA_2=row["IPA"]
      #calculate the distance and append it to the list of distances
      distance=lp.align.pairwise.edit_dist(IPA_1, IPA_2, normalized=True)
      distances.append(distance)

    #the distance between two languages as an average distance between all concepts
    average_distance = mean(distances)
    #write the distance into the confusion matrix, the two languages intersect in two places
    confusion[language1_ind][language2_ind]=average_distance
    confusion[language2_ind][language1_ind]=average_distance

    #REPORT progress
    print("writing languages number: ", language1_ind, language1, "and ", language2_ind, language2)

    language2_ind=language2_ind+1
  language1_ind=language1_ind+1
  language2_ind=0

print(confusion)
# Out:
# language list length:  37
# confusion list:  37
# ['Bengali' 'Hindi' 'Northern Pashto' 'Western Farsi' 'Northern Kurdish'
#  'Ossetian' 'Armenian' 'Modern Greek' 'Standard Albanian' 'Bulgarian'
#  'Croatian' 'Slovene' 'Slovak' 'Czech' 'Polish' 'Ukrainian' 'Belarusian'
#  'Russian' 'Lithuanian' 'Latvian' 'Icelandic' 'Norwegian (Bokmål)'
#  'Swedish' 'Danish' 'German' 'Dutch' 'English' 'Irish' 'Welsh' 'Breton'
#  'Latin' 'French' 'Catalan' 'Spanish' 'Portuguese' 'Italian' 'Romanian']
# writing languages number:  0 Bengali and  0 Bengali
# writing languages number:  0 Bengali and  1 Hindi
# writing languages number:  0 Bengali and  2 Northern Pashto
# writing languages number:  0 Bengali and  3 Western Farsi
# writing languages number:  0 Bengali and  4 Northern Kurdish
# writing languages number:  0 Bengali and  5 Ossetian
# writing languages number:  0 Bengali and  6 Armenian
# writing languages number:  0 Bengali and  7 Modern Greek
# writing languages number:  0 Bengali and  8 Standard Albanian
# writing languages number:  0 Bengali and  9 Bulgarian
# writing languages number:  0 Bengali and  10 Croatian
# writing languages number:  0 Bengali and  11 Slovene
# writing languages number:  0 Bengali and  12 Slovak
# writing languages number:  0 Bengali and  13 Czech
# writing languages number:  0 Bengali and  14 Polish
# writing languages number:  0 Bengali and  15 Ukrainian
# writing languages number:  0 Bengali and  16 Belarusian
# writing languages number:  0 Bengali and  17 Russian
# writing languages number:  0 Bengali and  18 Lithuanian
# writing languages number:  0 Bengali and  19 Latvian
# writing languages number:  0 Bengali and  20 Icelandic
# writing languages number:  0 Bengali and  21 Norwegian (Bokmål)
# writing languages number:  0 Bengali and  22 Swedish
# writing languages number:  0 Bengali and  23 Danish
# writing languages number:  0 Bengali and  24 German
# writing languages number:  0 Bengali and  25 Dutch
# writing languages number:  0 Bengali and  26 English
# writing languages number:  0 Bengali and  27 Irish
# writing languages number:  0 Bengali and  28 Welsh
# writing languages number:  0 Bengali and  29 Breton
# writing languages number:  0 Bengali and  30 Latin
# writing languages number:  0 Bengali and  31 French
# writing languages number:  0 Bengali and  32 Catalan
# writing languages number:  0 Bengali and  33 Spanish
# writing languages number:  0 Bengali and  34 Portuguese
# writing languages number:  0 Bengali and  35 Italian
# writing languages number:  0 Bengali and  36 Romanian
# writing languages number:  1 Hindi and  0 Bengali
# writing languages number:  1 Hindi and  1 Hindi
# writing languages number:  1 Hindi and  2 Northern Pashto
# writing languages number:  1 Hindi and  3 Western Farsi
# writing languages number:  1 Hindi and  4 Northern Kurdish
# writing languages number:  1 Hindi and  5 Ossetian
# writing languages number:  1 Hindi and  6 Armenian
# writing languages number:  1 Hindi and  7 Modern Greek
# writing languages number:  1 Hindi and  8 Standard Albanian
# writing languages number:  1 Hindi and  9 Bulgarian
# writing languages number:  1 Hindi and  10 Croatian
# writing languages number:  1 Hindi and  11 Slovene
# writing languages number:  1 Hindi and  12 Slovak
# writing languages number:  1 Hindi and  13 Czech
# writing languages number:  1 Hindi and  14 Polish
# writing languages number:  1 Hindi and  15 Ukrainian
# writing languages number:  1 Hindi and  16 Belarusian
# writing languages number:  1 Hindi and  17 Russian
# writing languages number:  1 Hindi and  18 Lithuanian
# writing languages number:  1 Hindi and  19 Latvian
# writing languages number:  1 Hindi and  20 Icelandic
# writing languages number:  1 Hindi and  21 Norwegian (Bokmål)
# writing languages number:  1 Hindi and  22 Swedish
# writing languages number:  1 Hindi and  23 Danish
# writing languages number:  1 Hindi and  24 German
# writing languages number:  1 Hindi and  25 Dutch
# writing languages number:  1 Hindi and  26 English
# writing languages number:  1 Hindi and  27 Irish
# writing languages number:  1 Hindi and  28 Welsh
# writing languages number:  1 Hindi and  29 Breton
# writing languages number:  1 Hindi and  30 Latin
# writing languages number:  1 Hindi and  31 French
# writing languages number:  1 Hindi and  32 Catalan
# writing languages number:  1 Hindi and  33 Spanish
# writing languages number:  5 Ossetian and  4 Northern Kurdish
# writing languages number:  5 Ossetian and  5 Ossetian
# writing languages number:  5 Ossetian and  6 Armenian
# writing languages number:  5 Ossetian and  7 Modern Greek
# writing languages number:  5 Ossetian and  8 Standard Albanian
# writing languages number:  5 Ossetian and  9 Bulgarian
# writing languages number:  5 Ossetian and  10 Croatian
# writing languages number:  5 Ossetian and  11 Slovene
# writing languages number:  5 Ossetian and  12 Slovak
# writing languages number:  5 Ossetian and  13 Czech
# writing languages number:  5 Ossetian and  14 Polish
# writing languages number:  5 Ossetian and  15 Ukrainian
# writing languages number:  5 Ossetian and  16 Belarusian
# writing languages number:  5 Ossetian and  17 Russian
# writing languages number:  5 Ossetian and  18 Lithuanian
# writing languages number:  5 Ossetian and  19 Latvian
# writing languages number:  5 Ossetian and  20 Icelandic
# writing languages number:  5 Ossetian and  21 Norwegian (Bokmål)
# writing languages number:  5 Ossetian and  22 Swedish
# writing languages number:  5 Ossetian and  23 Danish
# writing languages number:  5 Ossetian and  24 German
# writing languages number:  5 Ossetian and  25 Dutch
# writing languages number:  5 Ossetian and  26 English
# writing languages number:  5 Ossetian and  27 Irish
# writing languages number:  5 Ossetian and  28 Welsh
# writing languages number:  5 Ossetian and  29 Breton
# writing languages number:  5 Ossetian and  30 Latin
# writing languages number:  5 Ossetian and  31 French
# writing languages number:  5 Ossetian and  32 Catalan
# writing languages number:  5 Ossetian and  33 Spanish
# writing languages number:  5 Ossetian and  34 Portuguese
# writing languages number:  5 Ossetian and  35 Italian
# writing languages number:  5 Ossetian and  36 Romanian
# writing languages number:  6 Armenian and  0 Bengali
# writing languages number:  6 Armenian and  1 Hindi
# writing languages number:  6 Armenian and  2 Northern Pashto
# writing languages number:  6 Armenian and  3 Western Farsi
# writing languages number:  6 Armenian and  4 Northern Kurdish
# writing languages number:  6 Armenian and  5 Ossetian
# writing languages number:  6 Armenian and  6 Armenian
# writing languages number:  6 Armenian and  7 Modern Greek
# writing languages number:  6 Armenian and  8 Standard Albanian
# writing languages number:  6 Armenian and  9 Bulgarian
# writing languages number:  6 Armenian and  10 Croatian
# writing languages number:  6 Armenian and  11 Slovene
# writing languages number:  6 Armenian and  12 Slovak
# writing languages number:  6 Armenian and  13 Czech
# writing languages number:  6 Armenian and  14 Polish
# writing languages number:  6 Armenian and  15 Ukrainian
# writing languages number:  6 Armenian and  16 Belarusian
# writing languages number:  6 Armenian and  17 Russian
# writing languages number:  6 Armenian and  18 Lithuanian
# writing languages number:  6 Armenian and  19 Latvian
# writing languages number:  6 Armenian and  20 Icelandic
# writing languages number:  6 Armenian and  21 Norwegian (Bokmål)
# writing languages number:  6 Armenian and  22 Swedish
# writing languages number:  6 Armenian and  23 Danish
# writing languages number:  6 Armenian and  24 German
# writing languages number:  6 Armenian and  25 Dutch
# writing languages number:  6 Armenian and  26 English
# writing languages number:  6 Armenian and  27 Irish
# writing languages number:  6 Armenian and  28 Welsh
# writing languages number:  6 Armenian and  29 Breton
# writing languages number:  6 Armenian and  30 Latin
# writing languages number:  6 Armenian and  31 French
# writing languages number:  6 Armenian and  32 Catalan
# writing languages number:  6 Armenian and  33 Spanish
# writing languages number:  6 Armenian and  34 Portuguese
# writing languages number:  6 Armenian and  35 Italian
# writing languages number:  6 Armenian and  36 Romanian
# writing languages number:  7 Modern Greek and  0 Bengali
# writing languages number:  7 Modern Greek and  1 Hindi
# writing languages number:  7 Modern Greek and  2 Northern Pashto
# writing languages number:  7 Modern Greek and  3 Western Farsi
# writing languages number:  7 Modern Greek and  4 Northern Kurdish
# writing languages number:  7 Modern Greek and  5 Ossetian
# writing languages number:  7 Modern Greek and  6 Armenian
# writing languages number:  7 Modern Greek and  7 Modern Greek
# writing languages number:  7 Modern Greek and  8 Standard Albanian
# writing languages number:  7 Modern Greek and  9 Bulgarian
# writing languages number:  7 Modern Greek and  10 Croatian
# writing languages number:  7 Modern Greek and  11 Slovene
# writing languages number:  7 Modern Greek and  12 Slovak
# writing languages number:  7 Modern Greek and  13 Czech
# writing languages number:  7 Modern Greek and  14 Polish
# writing languages number:  7 Modern Greek and  15 Ukrainian
# writing languages number:  7 Modern Greek and  16 Belarusian
# writing languages number:  7 Modern Greek and  17 Russian
# writing languages number:  7 Modern Greek and  18 Lithuanian
# writing languages number:  7 Modern Greek and  19 Latvian
# writing languages number:  7 Modern Greek and  20 Icelandic
# writing languages number:  7 Modern Greek and  21 Norwegian (Bokmål)
# writing languages number:  7 Modern Greek and  22 Swedish
# writing languages number:  7 Modern Greek and  23 Danish
# writing languages number:  7 Modern Greek and  24 German
# writing languages number:  7 Modern Greek and  25 Dutch
# writing languages number:  7 Modern Greek and  26 English
# writing languages number:  7 Modern Greek and  27 Irish
# writing languages number:  7 Modern Greek and  28 Welsh
# writing languages number:  7 Modern Greek and  29 Breton
# writing languages number:  7 Modern Greek and  30 Latin
# writing languages number:  7 Modern Greek and  31 French
# writing languages number:  7 Modern Greek and  32 Catalan
# writing languages number:  7 Modern Greek and  33 Spanish
# writing languages number:  7 Modern Greek and  34 Portuguese
# writing languages number:  7 Modern Greek and  35 Italian
# writing languages number:  7 Modern Greek and  36 Romanian
# writing languages number:  8 Standard Albanian and  0 Bengali
# writing languages number:  8 Standard Albanian and  1 Hindi
# writing languages number:  8 Standard Albanian and  2 Northern Pashto
# writing languages number:  8 Standard Albanian and  3 Western Farsi
# writing languages number:  8 Standard Albanian and  4 Northern Kurdish
# writing languages number:  8 Standard Albanian and  5 Ossetian
# writing languages number:  8 Standard Albanian and  6 Armenian
# writing languages number:  8 Standard Albanian and  7 Modern Greek
# writing languages number:  8 Standard Albanian and  8 Standard Albanian
# writing languages number:  8 Standard Albanian and  9 Bulgarian
# writing languages number:  8 Standard Albanian and  10 Croatian
# writing languages number:  8 Standard Albanian and  11 Slovene
# writing languages number:  8 Standard Albanian and  12 Slovak
# writing languages number:  8 Standard Albanian and  13 Czech
# writing languages number:  8 Standard Albanian and  14 Polish
# writing languages number:  8 Standard Albanian and  15 Ukrainian
# writing languages number:  8 Standard Albanian and  16 Belarusian
# writing languages number:  8 Standard Albanian and  17 Russian
# writing languages number:  8 Standard Albanian and  18 Lithuanian
# writing languages number:  8 Standard Albanian and  19 Latvian
# writing languages number:  8 Standard Albanian and  20 Icelandic
# writing languages number:  8 Standard Albanian and  21 Norwegian (Bokmål)
# writing languages number:  8 Standard Albanian and  22 Swedish
# writing languages number:  8 Standard Albanian and  23 Danish
# writing languages number:  8 Standard Albanian and  24 German
# writing languages number:  8 Standard Albanian and  25 Dutch
# writing languages number:  8 Standard Albanian and  26 English
# writing languages number:  8 Standard Albanian and  27 Irish
# writing languages number:  8 Standard Albanian and  28 Welsh
# writing languages number:  8 Standard Albanian and  29 Breton
# writing languages number:  8 Standard Albanian and  30 Latin
# writing languages number:  8 Standard Albanian and  31 French
# writing languages number:  8 Standard Albanian and  32 Catalan
# writing languages number:  8 Standard Albanian and  33 Spanish
# writing languages number:  8 Standard Albanian and  34 Portuguese
# writing languages number:  8 Standard Albanian and  35 Italian
# writing languages number:  8 Standard Albanian and  36 Romanian
# writing languages number:  9 Bulgarian and  0 Bengali
# writing languages number:  9 Bulgarian and  1 Hindi
# writing languages number:  9 Bulgarian and  2 Northern Pashto
# writing languages number:  9 Bulgarian and  3 Western Farsi
# writing languages number:  9 Bulgarian and  4 Northern Kurdish
# writing languages number:  9 Bulgarian and  5 Ossetian
# writing languages number:  9 Bulgarian and  6 Armenian
# writing languages number:  9 Bulgarian and  7 Modern Greek
# writing languages number:  9 Bulgarian and  8 Standard Albanian
# writing languages number:  9 Bulgarian and  9 Bulgarian
# writing languages number:  9 Bulgarian and  10 Croatian
# writing languages number:  9 Bulgarian and  11 Slovene
# writing languages number:  9 Bulgarian and  12 Slovak
# writing languages number:  9 Bulgarian and  13 Czech
# writing languages number:  9 Bulgarian and  14 Polish
# writing languages number:  9 Bulgarian and  15 Ukrainian
# writing languages number:  9 Bulgarian and  16 Belarusian
# writing languages number:  9 Bulgarian and  17 Russian
# writing languages number:  9 Bulgarian and  18 Lithuanian
# writing languages number:  9 Bulgarian and  19 Latvian
# writing languages number:  9 Bulgarian and  20 Icelandic
# writing languages number:  9 Bulgarian and  21 Norwegian (Bokmål)
# writing languages number:  9 Bulgarian and  22 Swedish
# writing languages number:  9 Bulgarian and  23 Danish
# writing languages number:  9 Bulgarian and  24 German
# writing languages number:  9 Bulgarian and  25 Dutch
# writing languages number:  9 Bulgarian and  26 English
# writing languages number:  9 Bulgarian and  27 Irish
# writing languages number:  9 Bulgarian and  28 Welsh
# writing languages number:  9 Bulgarian and  29 Breton
# writing languages number:  9 Bulgarian and  30 Latin
# writing languages number:  9 Bulgarian and  31 French
# writing languages number:  9 Bulgarian and  32 Catalan
# writing languages number:  9 Bulgarian and  33 Spanish
# writing languages number:  9 Bulgarian and  34 Portuguese
# writing languages number:  9 Bulgarian and  35 Italian
# writing languages number:  9 Bulgarian and  36 Romanian
# writing languages number:  10 Croatian and  0 Bengali
# writing languages number:  10 Croatian and  1 Hindi
# writing languages number:  10 Croatian and  2 Northern Pashto
# writing languages number:  10 Croatian and  3 Western Farsi
# writing languages number:  10 Croatian and  4 Northern Kurdish
# writing languages number:  11 Slovene and  34 Portuguese
# writing languages number:  11 Slovene and  35 Italian
# writing languages number:  11 Slovene and  36 Romanian
# writing languages number:  12 Slovak and  0 Bengali
# writing languages number:  12 Slovak and  1 Hindi
# writing languages number:  12 Slovak and  2 Northern Pashto
# writing languages number:  12 Slovak and  3 Western Farsi
# writing languages number:  12 Slovak and  4 Northern Kurdish
# writing languages number:  12 Slovak and  5 Ossetian
# writing languages number:  12 Slovak and  6 Armenian
# writing languages number:  12 Slovak and  7 Modern Greek
# writing languages number:  12 Slovak and  8 Standard Albanian
# writing languages number:  12 Slovak and  9 Bulgarian
# writing languages number:  12 Slovak and  10 Croatian
# writing languages number:  12 Slovak and  11 Slovene
# writing languages number:  12 Slovak and  12 Slovak
# writing languages number:  12 Slovak and  13 Czech
# writing languages number:  12 Slovak and  14 Polish
# writing languages number:  12 Slovak and  15 Ukrainian
# writing languages number:  12 Slovak and  16 Belarusian
# writing languages number:  12 Slovak and  17 Russian
# writing languages number:  12 Slovak and  18 Lithuanian
# writing languages number:  12 Slovak and  19 Latvian
# writing languages number:  12 Slovak and  20 Icelandic
# writing languages number:  12 Slovak and  21 Norwegian (Bokmål)
# writing languages number:  12 Slovak and  22 Swedish
# writing languages number:  12 Slovak and  23 Danish
# writing languages number:  12 Slovak and  24 German
# writing languages number:  12 Slovak and  25 Dutch
# writing languages number:  12 Slovak and  26 English
# writing languages number:  12 Slovak and  27 Irish
# writing languages number:  12 Slovak and  28 Welsh
# writing languages number:  12 Slovak and  29 Breton
# writing languages number:  12 Slovak and  30 Latin
# writing languages number:  12 Slovak and  31 French
# writing languages number:  12 Slovak and  32 Catalan
# writing languages number:  12 Slovak and  33 Spanish
# writing languages number:  12 Slovak and  34 Portuguese
# writing languages number:  12 Slovak and  35 Italian
# writing languages number:  12 Slovak and  36 Romanian
# writing languages number:  13 Czech and  0 Bengali
# writing languages number:  13 Czech and  1 Hindi
# writing languages number:  13 Czech and  2 Northern Pashto
# writing languages number:  13 Czech and  3 Western Farsi
# writing languages number:  13 Czech and  4 Northern Kurdish
# writing languages number:  13 Czech and  5 Ossetian
# writing languages number:  13 Czech and  6 Armenian
# writing languages number:  13 Czech and  7 Modern Greek
# writing languages number:  13 Czech and  8 Standard Albanian
# writing languages number:  13 Czech and  9 Bulgarian
# writing languages number:  13 Czech and  10 Croatian
# writing languages number:  13 Czech and  11 Slovene
# writing languages number:  13 Czech and  12 Slovak
# writing languages number:  13 Czech and  13 Czech
# writing languages number:  13 Czech and  14 Polish
# writing languages number:  13 Czech and  15 Ukrainian
# writing languages number:  13 Czech and  16 Belarusian
# writing languages number:  13 Czech and  17 Russian
# writing languages number:  13 Czech and  18 Lithuanian
# writing languages number:  13 Czech and  19 Latvian
# writing languages number:  13 Czech and  20 Icelandic
# writing languages number:  13 Czech and  21 Norwegian (Bokmål)
# writing languages number:  13 Czech and  22 Swedish
# writing languages number:  13 Czech and  23 Danish
# writing languages number:  13 Czech and  24 German
# writing languages number:  13 Czech and  25 Dutch
# writing languages number:  13 Czech and  26 English
# writing languages number:  13 Czech and  27 Irish
# writing languages number:  13 Czech and  28 Welsh
# writing languages number:  13 Czech and  29 Breton
# writing languages number:  13 Czech and  30 Latin
# writing languages number:  13 Czech and  31 French
# writing languages number:  13 Czech and  32 Catalan
# writing languages number:  13 Czech and  33 Spanish
# writing languages number:  13 Czech and  34 Portuguese
# writing languages number:  13 Czech and  35 Italian
# writing languages number:  13 Czech and  36 Romanian
# writing languages number:  14 Polish and  0 Bengali
# writing languages number:  14 Polish and  1 Hindi
# writing languages number:  14 Polish and  2 Northern Pashto
# writing languages number:  14 Polish and  3 Western Farsi
# writing languages number:  14 Polish and  4 Northern Kurdish
# writing languages number:  14 Polish and  5 Ossetian
# writing languages number:  14 Polish and  6 Armenian
# writing languages number:  14 Polish and  7 Modern Greek
# writing languages number:  14 Polish and  8 Standard Albanian
# writing languages number:  14 Polish and  9 Bulgarian
# writing languages number:  14 Polish and  10 Croatian
# writing languages number:  14 Polish and  11 Slovene
# writing languages number:  14 Polish and  12 Slovak
# writing languages number:  14 Polish and  13 Czech
# writing languages number:  14 Polish and  14 Polish
# writing languages number:  14 Polish and  15 Ukrainian
# writing languages number:  14 Polish and  16 Belarusian
# writing languages number:  14 Polish and  17 Russian
# writing languages number:  14 Polish and  18 Lithuanian
# writing languages number:  14 Polish and  19 Latvian
# writing languages number:  14 Polish and  20 Icelandic
# writing languages number:  14 Polish and  21 Norwegian (Bokmål)
# writing languages number:  14 Polish and  22 Swedish
# writing languages number:  14 Polish and  23 Danish
# writing languages number:  14 Polish and  24 German
# writing languages number:  14 Polish and  25 Dutch
# writing languages number:  14 Polish and  26 English
# writing languages number:  14 Polish and  27 Irish
# writing languages number:  14 Polish and  28 Welsh
# writing languages number:  14 Polish and  29 Breton
# writing languages number:  14 Polish and  30 Latin
# writing languages number:  14 Polish and  31 French
# writing languages number:  14 Polish and  32 Catalan
# writing languages number:  14 Polish and  33 Spanish
# writing languages number:  14 Polish and  34 Portuguese
# writing languages number:  14 Polish and  35 Italian
# writing languages number:  14 Polish and  36 Romanian
# writing languages number:  15 Ukrainian and  0 Bengali
# writing languages number:  15 Ukrainian and  1 Hindi
# writing languages number:  15 Ukrainian and  2 Northern Pashto
# writing languages number:  15 Ukrainian and  3 Western Farsi
# writing languages number:  15 Ukrainian and  4 Northern Kurdish
# writing languages number:  15 Ukrainian and  5 Ossetian
# writing languages number:  15 Ukrainian and  6 Armenian
# writing languages number:  15 Ukrainian and  7 Modern Greek
# writing languages number:  15 Ukrainian and  8 Standard Albanian
# writing languages number:  15 Ukrainian and  9 Bulgarian
# writing languages number:  15 Ukrainian and  10 Croatian
# writing languages number:  15 Ukrainian and  11 Slovene
# writing languages number:  15 Ukrainian and  12 Slovak
# writing languages number:  15 Ukrainian and  13 Czech
# writing languages number:  15 Ukrainian and  14 Polish
# writing languages number:  15 Ukrainian and  15 Ukrainian
# writing languages number:  15 Ukrainian and  16 Belarusian
# writing languages number:  15 Ukrainian and  17 Russian
# writing languages number:  15 Ukrainian and  18 Lithuanian
# writing languages number:  15 Ukrainian and  19 Latvian
# writing languages number:  15 Ukrainian and  20 Icelandic
# writing languages number:  15 Ukrainian and  21 Norwegian (Bokmål)
# writing languages number:  15 Ukrainian and  22 Swedish
# writing languages number:  15 Ukrainian and  23 Danish
# writing languages number:  15 Ukrainian and  24 German
# writing languages number:  15 Ukrainian and  25 Dutch
# writing languages number:  15 Ukrainian and  26 English
# writing languages number:  15 Ukrainian and  27 Irish
# writing languages number:  15 Ukrainian and  28 Welsh
# writing languages number:  15 Ukrainian and  29 Breton
# writing languages number:  15 Ukrainian and  30 Latin
# writing languages number:  15 Ukrainian and  31 French
# writing languages number:  15 Ukrainian and  32 Catalan
# writing languages number:  15 Ukrainian and  33 Spanish
# writing languages number:  15 Ukrainian and  34 Portuguese
# writing languages number:  15 Ukrainian and  35 Italian
# writing languages number:  15 Ukrainian and  36 Romanian
# writing languages number:  16 Belarusian and  0 Bengali
# writing languages number:  16 Belarusian and  1 Hindi
# writing languages number:  16 Belarusian and  2 Northern Pashto
# writing languages number:  16 Belarusian and  3 Western Farsi
# writing languages number:  16 Belarusian and  4 Northern Kurdish
# writing languages number:  16 Belarusian and  5 Ossetian
# writing languages number:  16 Belarusian and  6 Armenian
# writing languages number:  16 Belarusian and  7 Modern Greek
# writing languages number:  16 Belarusian and  8 Standard Albanian
# writing languages number:  16 Belarusian and  9 Bulgarian
# writing languages number:  16 Belarusian and  10 Croatian
# writing languages number:  16 Belarusian and  11 Slovene
# writing languages number:  16 Belarusian and  12 Slovak
# writing languages number:  16 Belarusian and  13 Czech
# writing languages number:  16 Belarusian and  14 Polish
# writing languages number:  16 Belarusian and  15 Ukrainian
# writing languages number:  16 Belarusian and  16 Belarusian
# writing languages number:  16 Belarusian and  17 Russian
# writing languages number:  16 Belarusian and  18 Lithuanian
# writing languages number:  16 Belarusian and  19 Latvian
# writing languages number:  16 Belarusian and  20 Icelandic
# writing languages number:  16 Belarusian and  21 Norwegian (Bokmål)
# writing languages number:  16 Belarusian and  22 Swedish
# writing languages number:  16 Belarusian and  23 Danish
# writing languages number:  16 Belarusian and  24 German
# writing languages number:  16 Belarusian and  25 Dutch
# writing languages number:  16 Belarusian and  26 English
# writing languages number:  16 Belarusian and  27 Irish
# writing languages number:  16 Belarusian and  28 Welsh
# writing languages number:  16 Belarusian and  29 Breton
# writing languages number:  16 Belarusian and  30 Latin
# writing languages number:  16 Belarusian and  31 French
# writing languages number:  16 Belarusian and  32 Catalan
# writing languages number:  16 Belarusian and  33 Spanish
# writing languages number:  16 Belarusian and  34 Portuguese
# writing languages number:  16 Belarusian and  35 Italian
# writing languages number:  16 Belarusian and  36 Romanian
# writing languages number:  17 Russian and  0 Bengali
# writing languages number:  17 Russian and  1 Hindi
# writing languages number:  17 Russian and  2 Northern Pashto
# writing languages number:  17 Russian and  3 Western Farsi
# writing languages number:  17 Russian and  4 Northern Kurdish
# writing languages number:  17 Russian and  5 Ossetian
# writing languages number:  17 Russian and  6 Armenian
# writing languages number:  17 Russian and  7 Modern Greek
# writing languages number:  17 Russian and  8 Standard Albanian
# writing languages number:  20 Icelandic and  27 Irish
# writing languages number:  20 Icelandic and  28 Welsh
# writing languages number:  20 Icelandic and  29 Breton
# writing languages number:  20 Icelandic and  30 Latin
# writing languages number:  20 Icelandic and  31 French
# writing languages number:  20 Icelandic and  32 Catalan
# writing languages number:  20 Icelandic and  33 Spanish
# writing languages number:  20 Icelandic and  34 Portuguese
# writing languages number:  20 Icelandic and  35 Italian
# writing languages number:  20 Icelandic and  36 Romanian
# writing languages number:  21 Norwegian (Bokmål) and  0 Bengali
# writing languages number:  21 Norwegian (Bokmål) and  1 Hindi
# writing languages number:  21 Norwegian (Bokmål) and  2 Northern Pashto
# writing languages number:  21 Norwegian (Bokmål) and  3 Western Farsi
# writing languages number:  21 Norwegian (Bokmål) and  4 Northern Kurdish
# writing languages number:  21 Norwegian (Bokmål) and  5 Ossetian
# writing languages number:  21 Norwegian (Bokmål) and  6 Armenian
# writing languages number:  21 Norwegian (Bokmål) and  7 Modern Greek
# writing languages number:  21 Norwegian (Bokmål) and  8 Standard Albanian
# writing languages number:  21 Norwegian (Bokmål) and  9 Bulgarian
# writing languages number:  21 Norwegian (Bokmål) and  10 Croatian
# writing languages number:  21 Norwegian (Bokmål) and  11 Slovene
# writing languages number:  21 Norwegian (Bokmål) and  12 Slovak
# writing languages number:  21 Norwegian (Bokmål) and  13 Czech
# writing languages number:  21 Norwegian (Bokmål) and  14 Polish
# writing languages number:  21 Norwegian (Bokmål) and  15 Ukrainian
# writing languages number:  21 Norwegian (Bokmål) and  16 Belarusian
# writing languages number:  21 Norwegian (Bokmål) and  17 Russian
# writing languages number:  21 Norwegian (Bokmål) and  18 Lithuanian
# writing languages number:  21 Norwegian (Bokmål) and  19 Latvian
# writing languages number:  21 Norwegian (Bokmål) and  20 Icelandic
# writing languages number:  21 Norwegian (Bokmål) and  21 Norwegian (Bokmål)
# writing languages number:  21 Norwegian (Bokmål) and  22 Swedish
# writing languages number:  21 Norwegian (Bokmål) and  23 Danish
# writing languages number:  21 Norwegian (Bokmål) and  24 German
# writing languages number:  21 Norwegian (Bokmål) and  25 Dutch
# writing languages number:  21 Norwegian (Bokmål) and  26 English
# writing languages number:  21 Norwegian (Bokmål) and  27 Irish
# writing languages number:  21 Norwegian (Bokmål) and  28 Welsh
# writing languages number:  21 Norwegian (Bokmål) and  29 Breton
# writing languages number:  21 Norwegian (Bokmål) and  30 Latin
# writing languages number:  21 Norwegian (Bokmål) and  31 French
# writing languages number:  21 Norwegian (Bokmål) and  32 Catalan
# writing languages number:  21 Norwegian (Bokmål) and  33 Spanish
# writing languages number:  21 Norwegian (Bokmål) and  34 Portuguese
# writing languages number:  21 Norwegian (Bokmål) and  35 Italian
# writing languages number:  21 Norwegian (Bokmål) and  36 Romanian
# writing languages number:  22 Swedish and  0 Bengali
# writing languages number:  22 Swedish and  1 Hindi
# writing languages number:  22 Swedish and  2 Northern Pashto
# writing languages number:  22 Swedish and  3 Western Farsi
# writing languages number:  22 Swedish and  4 Northern Kurdish
# writing languages number:  22 Swedish and  5 Ossetian
# writing languages number:  22 Swedish and  6 Armenian
# writing languages number:  22 Swedish and  7 Modern Greek
# writing languages number:  22 Swedish and  8 Standard Albanian
# writing languages number:  22 Swedish and  9 Bulgarian
# writing languages number:  22 Swedish and  10 Croatian
# writing languages number:  22 Swedish and  11 Slovene
# writing languages number:  22 Swedish and  12 Slovak
# writing languages number:  22 Swedish and  13 Czech
# writing languages number:  22 Swedish and  14 Polish
# writing languages number:  22 Swedish and  15 Ukrainian
# ...
# writing languages number:  31 French and  7 Modern Greek
# writing languages number:  31 French and  8 Standard Albanian
# writing languages number:  31 French and  9 Bulgarian
# writing languages number:  31 French and  10 Croatian
# writing languages number:  31 French and  11 Slovene
# writing languages number:  31 French and  12 Slovak
# writing languages number:  31 French and  13 Czech
# writing languages number:  31 French and  14 Polish
# writing languages number:  31 French and  15 Ukrainian
# writing languages number:  31 French and  16 Belarusian
# writing languages number:  31 French and  17 Russian
# writing languages number:  31 French and  18 Lithuanian
# writing languages number:  31 French and  19 Latvian
# writing languages number:  31 French and  20 Icelandic
# writing languages number:  31 French and  21 Norwegian (Bokmål)
# writing languages number:  31 French and  22 Swedish
# writing languages number:  31 French and  23 Danish
# writing languages number:  31 French and  24 German
# writing languages number:  31 French and  25 Dutch
# writing languages number:  31 French and  26 English
# writing languages number:  31 French and  27 Irish
# writing languages number:  31 French and  28 Welsh
# writing languages number:  31 French and  29 Breton
# writing languages number:  31 French and  30 Latin
# writing languages number:  31 French and  31 French
# writing languages number:  31 French and  32 Catalan
# writing languages number:  31 French and  33 Spanish
# writing languages number:  31 French and  34 Portuguese
# writing languages number:  31 French and  35 Italian
# writing languages number:  31 French and  36 Romanian
# writing languages number:  32 Catalan and  0 Bengali
# writing languages number:  32 Catalan and  1 Hindi
# writing languages number:  32 Catalan and  2 Northern Pashto
# writing languages number:  32 Catalan and  3 Western Farsi
# writing languages number:  32 Catalan and  4 Northern Kurdish
# writing languages number:  32 Catalan and  5 Ossetian
# writing languages number:  32 Catalan and  6 Armenian
# writing languages number:  32 Catalan and  7 Modern Greek
# writing languages number:  32 Catalan and  8 Standard Albanian
# writing languages number:  32 Catalan and  9 Bulgarian
# writing languages number:  32 Catalan and  10 Croatian
# writing languages number:  32 Catalan and  11 Slovene
# writing languages number:  32 Catalan and  12 Slovak
# writing languages number:  32 Catalan and  13 Czech
# writing languages number:  32 Catalan and  14 Polish
# writing languages number:  32 Catalan and  15 Ukrainian
# writing languages number:  32 Catalan and  16 Belarusian
# writing languages number:  32 Catalan and  17 Russian
# writing languages number:  32 Catalan and  18 Lithuanian
# writing languages number:  32 Catalan and  19 Latvian
# writing languages number:  32 Catalan and  20 Icelandic
# writing languages number:  32 Catalan and  21 Norwegian (Bokmål)
# writing languages number:  32 Catalan and  22 Swedish
# writing languages number:  32 Catalan and  23 Danish
# writing languages number:  32 Catalan and  24 German
# writing languages number:  32 Catalan and  25 Dutch
# writing languages number:  32 Catalan and  26 English
# writing languages number:  32 Catalan and  27 Irish
# writing languages number:  32 Catalan and  28 Welsh
# writing languages number:  32 Catalan and  29 Breton
# writing languages number:  32 Catalan and  30 Latin
# writing languages number:  32 Catalan and  31 French
# writing languages number:  32 Catalan and  32 Catalan
# writing languages number:  32 Catalan and  33 Spanish
# writing languages number:  32 Catalan and  34 Portuguese
# writing languages number:  32 Catalan and  35 Italian
# writing languages number:  32 Catalan and  36 Romanian
# writing languages number:  33 Spanish and  0 Bengali
# writing languages number:  33 Spanish and  1 Hindi
# writing languages number:  33 Spanish and  2 Northern Pashto
# writing languages number:  33 Spanish and  3 Western Farsi
# writing languages number:  33 Spanish and  4 Northern Kurdish
# writing languages number:  33 Spanish and  5 Ossetian
# writing languages number:  33 Spanish and  6 Armenian
# writing languages number:  33 Spanish and  7 Modern Greek
# writing languages number:  33 Spanish and  8 Standard Albanian
# writing languages number:  33 Spanish and  9 Bulgarian
# writing languages number:  33 Spanish and  10 Croatian
# writing languages number:  33 Spanish and  11 Slovene
# writing languages number:  33 Spanish and  12 Slovak
# writing languages number:  33 Spanish and  13 Czech
# writing languages number:  33 Spanish and  14 Polish
# writing languages number:  33 Spanish and  15 Ukrainian
# writing languages number:  33 Spanish and  16 Belarusian
# writing languages number:  33 Spanish and  17 Russian
# writing languages number:  33 Spanish and  18 Lithuanian
# writing languages number:  33 Spanish and  19 Latvian
# writing languages number:  33 Spanish and  20 Icelandic
# writing languages number:  33 Spanish and  21 Norwegian (Bokmål)
# writing languages number:  33 Spanish and  22 Swedish
# writing languages number:  33 Spanish and  23 Danish
# writing languages number:  33 Spanish and  24 German
# writing languages number:  33 Spanish and  25 Dutch
# writing languages number:  33 Spanish and  26 English
# writing languages number:  33 Spanish and  27 Irish
# writing languages number:  33 Spanish and  28 Welsh
# writing languages number:  33 Spanish and  29 Breton
# writing languages number:  33 Spanish and  30 Latin
# writing languages number:  33 Spanish and  31 French
# writing languages number:  33 Spanish and  32 Catalan
# writing languages number:  33 Spanish and  33 Spanish
# writing languages number:  33 Spanish and  34 Portuguese
# writing languages number:  33 Spanish and  35 Italian
# writing languages number:  33 Spanish and  36 Romanian
# writing languages number:  34 Portuguese and  0 Bengali
# writing languages number:  34 Portuguese and  1 Hindi
# writing languages number:  34 Portuguese and  2 Northern Pashto
# writing languages number:  34 Portuguese and  3 Western Farsi
# writing languages number:  34 Portuguese and  4 Northern Kurdish
# writing languages number:  34 Portuguese and  5 Ossetian
# writing languages number:  34 Portuguese and  6 Armenian
# writing languages number:  34 Portuguese and  7 Modern Greek
# writing languages number:  34 Portuguese and  8 Standard Albanian
# writing languages number:  34 Portuguese and  9 Bulgarian
# writing languages number:  34 Portuguese and  10 Croatian
# writing languages number:  34 Portuguese and  11 Slovene
# writing languages number:  34 Portuguese and  12 Slovak
# writing languages number:  34 Portuguese and  13 Czech
# writing languages number:  34 Portuguese and  14 Polish
# writing languages number:  34 Portuguese and  15 Ukrainian
# writing languages number:  34 Portuguese and  16 Belarusian
# writing languages number:  34 Portuguese and  17 Russian
# writing languages number:  34 Portuguese and  18 Lithuanian
# writing languages number:  34 Portuguese and  19 Latvian
# writing languages number:  34 Portuguese and  20 Icelandic
# writing languages number:  34 Portuguese and  21 Norwegian (Bokmål)
# writing languages number:  34 Portuguese and  22 Swedish
# writing languages number:  34 Portuguese and  23 Danish
# writing languages number:  34 Portuguese and  24 German
# writing languages number:  34 Portuguese and  25 Dutch
# writing languages number:  34 Portuguese and  26 English
# writing languages number:  34 Portuguese and  27 Irish
# writing languages number:  34 Portuguese and  28 Welsh
# writing languages number:  34 Portuguese and  29 Breton
# writing languages number:  34 Portuguese and  30 Latin
# writing languages number:  34 Portuguese and  31 French
# writing languages number:  34 Portuguese and  32 Catalan
# writing languages number:  34 Portuguese and  33 Spanish
# writing languages number:  34 Portuguese and  34 Portuguese
# writing languages number:  34 Portuguese and  35 Italian
# writing languages number:  34 Portuguese and  36 Romanian
# writing languages number:  35 Italian and  0 Bengali
# writing languages number:  35 Italian and  1 Hindi
# writing languages number:  35 Italian and  2 Northern Pashto
# writing languages number:  35 Italian and  3 Western Farsi
# writing languages number:  35 Italian and  4 Northern Kurdish
# writing languages number:  35 Italian and  5 Ossetian
# writing languages number:  35 Italian and  6 Armenian
# writing languages number:  35 Italian and  7 Modern Greek
# writing languages number:  35 Italian and  8 Standard Albanian
# writing languages number:  35 Italian and  9 Bulgarian
# writing languages number:  35 Italian and  10 Croatian
# writing languages number:  35 Italian and  11 Slovene
# writing languages number:  35 Italian and  12 Slovak
# writing languages number:  35 Italian and  13 Czech
# writing languages number:  35 Italian and  14 Polish
# writing languages number:  35 Italian and  15 Ukrainian
# writing languages number:  35 Italian and  16 Belarusian
# writing languages number:  35 Italian and  17 Russian
# writing languages number:  35 Italian and  18 Lithuanian
# writing languages number:  35 Italian and  19 Latvian
# writing languages number:  35 Italian and  20 Icelandic
# writing languages number:  35 Italian and  21 Norwegian (Bokmål)
# writing languages number:  35 Italian and  22 Swedish
# writing languages number:  35 Italian and  23 Danish
# writing languages number:  35 Italian and  24 German
# writing languages number:  35 Italian and  25 Dutch
# writing languages number:  35 Italian and  26 English
# writing languages number:  35 Italian and  27 Irish
# writing languages number:  35 Italian and  28 Welsh
# writing languages number:  35 Italian and  29 Breton
# writing languages number:  35 Italian and  30 Latin
# writing languages number:  35 Italian and  31 French
# writing languages number:  35 Italian and  32 Catalan
# writing languages number:  35 Italian and  33 Spanish
# writing languages number:  35 Italian and  34 Portuguese
# writing languages number:  35 Italian and  35 Italian
# writing languages number:  35 Italian and  36 Romanian
# writing languages number:  36 Romanian and  0 Bengali
# writing languages number:  36 Romanian and  1 Hindi
# writing languages number:  36 Romanian and  2 Northern Pashto
# writing languages number:  36 Romanian and  3 Western Farsi
# writing languages number:  36 Romanian and  4 Northern Kurdish
# writing languages number:  36 Romanian and  5 Ossetian
# writing languages number:  36 Romanian and  6 Armenian
# writing languages number:  36 Romanian and  7 Modern Greek
# writing languages number:  36 Romanian and  8 Standard Albanian
# writing languages number:  36 Romanian and  9 Bulgarian
# writing languages number:  36 Romanian and  10 Croatian
# writing languages number:  36 Romanian and  11 Slovene
# writing languages number:  36 Romanian and  12 Slovak
# writing languages number:  36 Romanian and  13 Czech
392, 0.6930916305916306, 0.6964790764790765, 0.6876114734938265, 0.6604739704739705, 0.7105605505605506, 0.6799633699633699, 0.6498024198024198], [0.6226738174106595, 0.6243376652587179, 0.6354628412523149, 0.0, 0.598965478965479, 0.6220737741790373, 0.6892694074930917, 0.7332143879512301, 0.7067759141443352, 0.674137908874751, 0.6499114920167551, 0.666782398887662, 0.67311337785022, 0.6451204935415462, 0.6746809331019857, 0.6970618854829381, 0.7181689810017984, 0.7026305273673695, 0.6544905240957872, 0.6815809336861969, 0.7290789838816154, 0.732411623464255, 0.7497578444946866, 0.7342725403251719, 0.7417163538216169, 0.7079318926687348, 0.7478239888766205, 0.7282760939610785, 0.7384615968826496, 0.7115346349556876, 0.7216515575068206, 0.6795596216648848, 0.6757587544894046, 0.6722120569488991, 0.7175667023035444, 0.6731407189301927, 0.6189370863055074], [0.6621979190400243, 0.6112618667881826, 0.6086909581646424, 0.598965478965479, 0.0, 0.6371831092883724, 0.6744111001657441, 0.7237593984962406, 0.6697319055213792, 0.66633553580922, 0.6663773069036227, 0.6649069643806486, 0.633777625882889, 0.6414521735574367, 0.6403987825040457, 0.6724120908331435, 0.705378720866337, 0.6926768260978787, 0.690178038335933, 0.6579570137464874, 0.7226273069036226, 0.7280147338042076, 0.732381711855396, 0.7080022024758866, 0.7065626186678818, 0.6921219715956558, 0.7265535049745576, 0.7361700653148021, 0.677459791670318, 0.7362558494137441, 0.7022899907110434, 0.7085501632870054, 0.6679510891585195, 0.6770046327941065, 0.6825852510063036, 0.6877669698722331, 0.7007711002447845], [0.6563275613275613, 0.6551461038961038, 0.6106893106893106, 0.6220737741790373, 0.6371831092883724, 0.0, 0.7008637849079026, 0.7334199134199134, 0.7414141414141414, 0.638023088023088, 0.6625685425685426, 0.6263780663780664, 0.6551659451659452, 0.6113131313131314, 0.6493506493506493, 0.647020202020202, 0.6355873864697394, 0.6570310245310246, 0.6657944832944833, 0.6432034632034632, 0.7 ...

# %% [markdown]
# Now that we have computed a matrix of similarities, we can use clustering algorithms to try to build phylogenetic trees representing the languages historical relationships. First, let's use the `lp.algorithm.clustering.flat_cluster` function from `lingpy` to derive a flat clustering of languages.

# %%
#language_names=list(languages["Language_ID"].values)

#Couldn't solve errors with given code to cluster actual names, go by numbers corresponding to language names
for i in range(len(language_list)):
  print (i, language_list[i])

print("")
lp.algorithm.clustering.flat_cluster('upgma', 0.6, confusion)
# Out:
# 0 Bengali
# 1 Hindi
# 2 Northern Pashto
# 3 Western Farsi
# 4 Northern Kurdish
# 5 Ossetian
# 6 Armenian
# 7 Modern Greek
# 8 Standard Albanian
# 9 Bulgarian
# 10 Croatian
# 11 Slovene
# 12 Slovak
# 13 Czech
# 14 Polish
# 15 Ukrainian
# 16 Belarusian
# 17 Russian
# 18 Lithuanian
# 19 Latvian
# 20 Icelandic
# 21 Norwegian (Bokmål)
# 22 Swedish
# 23 Danish
# 24 German
# 25 Dutch
# 26 English
# 27 Irish
# 28 Welsh
# 29 Breton
# 30 Latin
# 31 French
# 32 Catalan
# 33 Spanish
# 34 Portuguese
# 35 Italian
# 36 Romanian
# {0: [0],
#  1: [1],
#  2: [2],
#  3: [3, 4],
#  5: [5],
#  6: [6],
#  7: [7],
#  8: [8],
#  18: [18, 19, 9, 12, 14, 13, 16, 17, 15, 10, 11],
#  24: [24, 25, 20, 21, 22, 23, 26],
#  27: [27],
#  28: [28, 29],
#  30: [30],
#  31: [31],
#  32: [32, 33, 34, 35, 36]}

# %% [markdown]
# ***Question 5:*** Do you recognize any of the clusters of languages? Are there any noteworthy errors in this clustering?
#
# **Q5: put your answer here (please keep it brief, no more than 4-5 sentences.)**
#
# It seems that the clustering method is picking up on correct groupings:
# * The biggest cluster after "18:" contains the Balto-slavic languages.
# * Second biggest cluster under "24:" are the Germanic languages.
# * Welsh and Breton (28, 29) are Celtic languages.
# * Languages 32-36 are Romance languages (subgroup of Italic)
# * Western Farsi and Northern Kurdish (3-4) are Iranian languages.
#
# However, many languages remain ungrouped even if they could be closer to some clusters than others, e.g. French could be grouped with Romance languages but is not being clustered with them.

# %% [markdown]
# Now we will build our own dendrogram using the clustering algorithms available in [`scipy`](https://docs.scipy.org/doc/scipy/reference/cluster.hierarchy.html). You can read in particular about the [`linkage`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.linkage.html) function and the [`dendrogram`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.dendrogram.html) function.

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import v_measure_score
import matplotlib.pyplot as plt
import scipy


#making the matrix only the upper triangle without repetition 
confusion2= [[0 for j in range(len(language_list))] for i in range(len(language_list))]
max_col=36
for i in range(36):
  for j in range(max_col):
    confusion2[i][j] = confusion[i][j]
  max_col = max_col-1


#Problem 4: use the linkage function with the average linkage method to compute the clustering.
linked = scipy.cluster.hierarchy.linkage(confusion2, method="centroid")


#plot the results using dendrogram

#Rewrote this to label names without errors
def llf(id):
    if id < 36:
        return language_list[id]
    else:
        return


#def llf(id): return list(languages["Language_ID"].values)[id]
plt.figure(figsize=(18, 7))
dendrogram(linked,
           p=100,
           truncate_mode="level",
           orientation='top',
           distance_sort='descending',
           show_leaf_counts=False,
           leaf_label_func=llf)

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix

# %% [markdown]
# ***Question 6:*** Do you recognize any of the clusters of languages at any of the levels? Are there any noteworthy erros in this clustering?
#
# **Q6: put your answer here (please keep it brief, no more than 4-5 sentences.)**
#
# Lookig at the "centroid" method with 20 concepts.
# In the reference wikipedia image, the Iranian and Indo-Aryan languages are closely linked, this is also shown in the green cluster even if some details are wrong. The red cluster groups the romantic languages. In teal clusters, Balto-slavic languages are mostly grouped closer to each other.
# Some errors are that e.g. "Danish" is among Balto-Slavic neighbours instead of the Germanic group.
#
#
# ***Question 7:*** Try three of the other linkage methods and describe how the change the results.
#
# **Q7: put your answer here (please keep it brief, no more than 4-5 sentences.)**
#
#
# ***Question 8:*** Try increasing the number of concepts we use to compute our confusion matrix to be higher than 20. Does it change the results?
#
# **Q8: put your answer here (please keep it brief, no more than 3-4 sentences.)**
#
# Running this with 50 concepts and "centroid" method. There are fewer clusters, with teal and red merging into red, suggesting that more data made the languages appear more similar. If running with even more data, one would expect the clustering to become more accurate compared to reference.
#
# ![50 concepts.jpg](data:image/jpeg;base64,...)
